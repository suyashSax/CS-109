# %%
x = [10, 20, 30, 40, 50]
for item in x:
    print "Item is ", item
# Out:
# Item is  10
# Item is  20
# Item is  30
# Item is  40
# Item is  50

# %%
# !pip install BeautifulSoup seaborn pyquery
# Out:
# Requirement already satisfied: BeautifulSoup in /Users/Sachin/anaconda/lib/python2.7/site-packages
# Requirement already satisfied: seaborn in /Users/Sachin/anaconda/lib/python2.7/site-packages
# Requirement already satisfied: pyquery in /Users/Sachin/anaconda/lib/python2.7/site-packages
# Requirement already satisfied: cssselect>0.7.9 in /Users/Sachin/anaconda/lib/python2.7/site-packages (from pyquery)
# Requirement already satisfied: lxml>=2.1 in /Users/Sachin/anaconda/lib/python2.7/site-packages (from pyquery)

# %%
#IPython is what you are using now to run the notebook
import IPython
print "IPython version:      %6.6s (need at least 3.0.0)" % IPython.__version__

# Numpy is a library for working with Arrays
import numpy as np
print "Numpy version:        %6.6s (need at least 1.9.1)" % np.__version__

# SciPy implements many different numerical algorithms
import scipy as sp
print "SciPy version:        %6.6s (need at least 0.15.1)" % sp.__version__

# Pandas makes working with data tables easier
import pandas as pd
print "Pandas version:       %6.6s (need at least 0.16.2)" % pd.__version__

# Module for plotting
import matplotlib
print "Mapltolib version:    %6.6s (need at least 1.4.1)" % matplotlib.__version__

# SciKit Learn implements several Machine Learning algorithms
import sklearn
print "Scikit-Learn version: %6.6s (need at least 0.16.1)" % sklearn.__version__

# Requests is a library for getting data from the Web
import requests
print "requests version:     %6.6s (need at least 2.0.0)" % requests.__version__

#BeautifulSoup is a library to parse HTML and XML documents
import bs4
print "BeautifulSoup version:%6.6s (need at least 4.4)" % bs4.__version__

import pyquery
print "Loaded PyQuery"
# Out:
# IPython version:       4.2.0 (need at least 3.0.0)
# Numpy version:        1.13.1 (need at least 1.9.1)
# SciPy version:        0.17.1 (need at least 0.15.1)
# Pandas version:       0.20.3 (need at least 0.16.2)
# Mapltolib version:     1.5.1 (need at least 1.4.1)
# Scikit-Learn version: 0.18.2 (need at least 0.16.1)
# requests version:     2.13.0 (need at least 2.0.0)
# BeautifulSoup version: 4.4.1 (need at least 4.4)
# Loaded PyQuery

# %%
# %matplotlib inline

# %%
import numpy as np # imports a fast numerical programming library
import scipy as sp #imports stats functions, amongst other things
import matplotlib as mpl # this actually imports matplotlib
import matplotlib.cm as cm #allows us easy access to colormaps
import matplotlib.pyplot as plt #sets up plotting under plt
import pandas as pd #lets us handle data as dataframes
import seaborn as sns #sets up styles and gives us more plotting options

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)

# %%
x = np.linspace(0, 10, 30)  #array of 30 points from 0 to 10
y = np.sin(x)
z = y + np.random.normal(size=30) * .2 # randomisation gives non-smooth - "noisy" sine
plt.plot(x, y, 'o-', label='A sine wave')
plt.plot(x, z, '-', label='Noisy sine')
plt.legend(loc = 'lower right')
plt.xlabel("X axis")
plt.ylabel("Y axis")

# %%
z = y + np.random.normal(size=30) * .2 
plt.plot(x, z, '-', label='Noisy sine')
# randomisation used, so expect different curve

# %%
print "Make a 3 row x 4 column array of random numbers"
x = np.random.random((3, 4))
print x
# Out:
# Make a 3 row x 4 column array of random numbers
# [[ 0.86474145  0.86957317  0.20766361  0.32902904]
#  [ 0.86030714  0.0775894   0.44818749  0.37127199]
#  [ 0.77113142  0.09082003  0.62261432  0.773559  ]]

# %%
print "Add 1 to every element"
# x refers to the entire matrix, addition is element by element
x = x + 1
print x
# Out:
# Add 1 to every element
# [[ 1.86474145  1.86957317  1.20766361  1.32902904]
#  [ 1.86030714  1.0775894   1.44818749  1.37127199]
#  [ 1.77113142  1.09082003  1.62261432  1.773559  ]]

# %%
print "Get the element at row 1, column 2"
print x[1, 2]
# Out:
# Get the element at row 1, column 2
# 1.44818749102

# %%
# The colon syntax is called "slicing" the array. 
print "Get the first row"
print x[0, :]
# Out:
# Get the first row
# [ 1.86474145  1.86957317  1.20766361  1.32902904]

# %%
print "Get the first col"
print x[:, 0]
# Out:
# Get the first col
# [ 1.86474145  1.86030714  1.77113142]

# %%
print "Get every 2nd column of the first row"
print x[0, ::2]

#0, 2, 4 ...
# Out:
# Get every 2nd column of the first row
# [ 1.86474145  1.20766361]

# %%
print "Max is  ", x.max()
print "Min is  ", x.min()
print "Mean is ", x.mean()
# Out:
# Max is   1.86957316771
# Min is   1.07758940054
# Mean is  1.52387400456

# %%
# Call the x.max function again, but use the axis keyword to print the maximum of each row in x

# axis = 0 i.e. max value in each of 4 cols
# axis = 1 i.e. max value in each of 3 rows

print x.max(axis=0)  
print x.max(axis=1)
# Out:
# [ 1.86474145  1.86957317  1.62261432  1.773559  ]
# [ 1.86957317  1.86030714  1.773559  ]

# %%
# Probability distribution simulations:

# Binomial w/ n = 500 and p = 0.5 eg. 500 coin tosses
x = np.random.binomial(500, .5)
print "number of heads:", x
# Out:
# number of heads: 249

# %%
# Use the plt.hist() function to plot a histogram of the number of Heads (1s) in 500 sims

# declare empty array
heads = [] 

# run 500 sims
for i in range(500):
    heads.append(np.random.binomial(500, .5))

# plot
histogram = plt.hist(heads, bins=10)

# %%
# alternatively,

# "list comprehension"
heads = [np.random.binomial(500, .5) for i in range(500)]

# pure numpy
heads = np.random.binomial(500, .5, size=500)

# %%
# return dimensionality
heads.shape
# Out:
# (500,)

# %%
"""
Function
--------
simulate_prizedoor

Generate a random array of 0s, 1s, and 2s, representing
hiding a prize between door 0, door 1, and door 2

Parameters
----------
nsim : int
    The number of simulations to run

Returns
-------
sims : array
    Random array of 0s, 1s, and 2s

Example
-------
>>> print simulate_prizedoor(3)
array([0, 0, 2])
"""

def simulate_prizedoor(nsim):
    return np.random.randint(0, 3, (nsim)) # 0, 1, 2 so bounds 0, 3 i.e. [lo, hi)

# %%
simulate_prizedoor(3)
# Out:
# array([2, 1, 0])

# %%
"""
Function
--------
simulate_guess

Return any strategy for guessing which door a prize is behind. This
could be a random strategy, one that always guesses 2, whatever.

Parameters
----------
nsim : int
    The number of simulations to generate guesses for

Returns
-------
guesses : array
    An array of guesses. Each guess is a 0, 1, or 2

Example
-------
>>> print simulate_guess(5)
array([0, 0, 0, 0, 0])
"""

# same randomisation as above
def simulate_guess(nsim):
    return np.random.randint(0, 3, (nsim))

# %%
simulate_guess(3)
# Out:
# array([1, 0, 0])

# %%
"""
Function
--------
switch_guess

The strategy that always switches a guess after the goat door is opened

Parameters
----------
guesses : array
     Array of original guesses, for each simulation
goatdoors : array
     Array of revealed goat doors for each simulation

Returns
-------
The new door after switching. Should be different from both guesses and goatdoors

Examples
--------
>>> print switch_guess(np.array([0, 1, 2]), np.array([1, 2, 1]))
>>> array([2, 0, 0])
"""

def result(x, y):
    possibilites = [0, 1, 2]
    if (x == y):
        return not x in possibilities.any()
    else:
        return not x in possibilites.any() and not y in possibilies.any()

def switch_guess(guesses, goatdoors):
    res = []
    for i in range(len(guesses)):
        res.append(result(guesses[i], goatdoors[i]))

# %%
"""
Function
--------
goat_door

Simulate the opening of a "goat door" that doesn't contain the prize,
and is different from the contestants guess

Parameters
----------
prizedoors : array
    The door that the prize is behind in each simulation
guesses : array
    THe door that the contestant guessed in each simulation

Returns
-------
goats : array
    The goat door that is opened for each simulation. Each item is 0, 1, or 2, and is different
    from both prizedoors and guesses

Examples
--------
>>> print goat_door(np.array([0, 1, 2]), np.array([1, 1, 1]))
>>> array([2, 2, 0])
"""

def result(x, y):
    tup = (x,y)
    if tup == (0,0):
        return np.random.randint(1,3)
    if tup == (1,1):
        return 0 if np.random.randint(0,2) else 2
    if tup == (2,2):
        return np.random.randint(0,2)
    if tup == (0,1) or tup == (1,0):
        return 2
    if tup == (0,2) or tup == (2,0):
        return 1
    if tup == (1,2) or tup == (2,1):
        return 0
    
def goat_door(prizedoors, guesses):
    res = []
    for door, guess in zip(prizedoors, guesses):
        res.append(result(door, guess))
    return res

# %%
print goat_door(np.array([0, 1, 2]), np.array([1, 1, 1]))
# Out:
# [2, 2, 0]
